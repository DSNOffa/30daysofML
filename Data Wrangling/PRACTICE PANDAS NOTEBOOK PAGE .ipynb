# %% [markdown]
# # INTRODUCTION TO PANDAS
#
# Pandas is basically used to read all kinds of including CSV files, excel files, JASON files. This is because it has more flexibilitu and allows you to work with larger datasets.

# %%
import pandas as pd

# %%
# import pandas as pd

df = pd.read_csv(r'C:\Users\HP\Desktop\codellc\Artificial Intelligence\ML-Week3\datasets\pokemon_data.csv')

# %%
pd.read_excel('filepath.xlsx')

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %%
# LOADING IN EXCEL FILES

# %%
df_xlsx = pd.read_excel('./Desktop/Artificial Intelligence/ML-Week3/pokemon_data.xlsx')

# %%
df_xlsx
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_xlsx.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# LOADING TXT FILES
# It must involve the use of a delimiter which is usually '\t'

# %%
pd.read

# %%
df3 = pd.read_csv('./Desktop/Artificial Intelligence/ML-Week3/pokemon_data.txt')

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3357e37d2add> in <module>
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
df3 = pd.read_csv('./Desktop/Artificial Intelligence/ML-Week3/pokemon_data.txt', delimiter='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2ee3bf647e91> in <module>
# ----> 1 df3 = pd.read_csv('./Desktop/Artificial Intelligence/ML-Week3/pokemon_data.txt', sep='\t')
#
# C:\Users\Public\New folder\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
df3

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %% [markdown]
# # READING DATAS IN PANDAS

# %%
# Reading header i.e Column

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Reading a specific column

# %%
df['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
print (df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print (df['Name'][3:200])
# Out:
# 3          VenusaurMega Venusaur
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 7      CharizardMega Charizard X
#                  ...
# 195                     Ampharos
# 196        AmpharosMega Ampharos
# 197                    Bellossom
# 198                       Marill
# 199                    Azumarill
# Name: Name, Length: 197, dtype: object

# %%
print (df['Name'][50])
# Out:
# Vileplume

# %%
# Reading multiple specific headers
 # You have to use double columns to indicate several lists whenever you want to print multiple headers.

# %%
print (df[['Name', 'Type 2', 'Defense']])
# Out:
#                       Name  Type 2  Defense
# 0                Bulbasaur  Poison       49
# 1                  Ivysaur  Poison       63
# 2                 Venusaur  Poison       83
# 3    VenusaurMega Venusaur  Poison      123
# 4               Charmander     NaN       43
# ..                     ...     ...      ...
# 795                Diancie   Fairy      150
# 796    DiancieMega Diancie   Fairy      110
# 797    HoopaHoopa Confined   Ghost       60
# 798     HoopaHoopa Unbound    Dark       60
# 799              Volcanion   Water      120
#
# [800 rows x 3 columns]

# %%
# Reading an index i.e Rows
# iloc means integer location

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
print (df.iloc[50])
# Out:
# #                    45
# Name          Vileplume
# Type 1            Grass
# Type 2           Poison
# HP                   75
# Attack               80
# Defense              85
# Sp. Atk             110
# Sp. Def              90
# Speed                50
# Generation            1
# Legendary         False
# Name: 50, dtype: object

# %%
print (df.iloc[3:8])
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False

# %%
# Reading a specific location in the dataframe
# This make use of index numbers for both rows and columns
# this is the format: print(df.iloc[rows,columns])

# %%
print(df.iloc[6,2])
# Out:
# Fire

# %%
df.iloc[505,5]
# Out:
# 100

# %%
for index, row in df.iterrows():
    print(index,row ["Defense"])
# Out:
# 0 49
# 1 63
# 2 83
# 3 123
# 4 43
# 5 58
# 6 78
# 7 111
# 8 78
# 9 65
# 10 80
# 11 100
# 12 120
# 13 35
# 14 55
# 15 50
# 16 30
# 17 50
# 18 40
# 19 40
# 20 40
# 21 55
# 22 75
# 23 80
# 24 35
# 25 60
# 26 30
# 27 65
# 28 44
# 29 69
# 30 40
# 31 55
# 32 85
# 33 110
# 34 52
# 35 67
# 36 87
# 37 40
# 38 57
# 39 77
# 40 48
# 41 73
# 42 40
# 43 75
# 44 20
# 45 45
# 46 35
# 47 70
# 48 55
# 49 70
# 50 85
# 51 55
# 52 80
# 53 50
# 54 60
# 55 25
# 56 50
# 57 35
# 58 60
# 59 48
# 60 78
# 61 35
# 62 60
# 63 45
# 64 80
# 65 40
# 66 65
# 67 95
# 68 15
# 69 30
# 70 45
# 71 65
# 72 50
# 73 70
# 74 80
# 75 35
# 76 50
# 77 65
# 78 35
# 79 65
# 80 100
# 81 115
# 82 130
# 83 55
# 84 70
# 85 65
# 86 110
# 87 180
# 88 70
# 89 95
# 90 55
# 91 45
# 92 70
# 93 55
# 94 80
# 95 50
# 96 75
# 97 100
# 98 180
# 99 30
# 100 45
# 101 60
# 102 80
# 103 160
# 104 45
# 105 70
# 106 90
# 107 115
# 108 50
# 109 70
# 110 80
# 111 85
# 112 95
# 113 110
# 114 53
# 115 79
# 116 75
# 117 95
# 118 120
# 119 95
# 120 120
# ...

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.loc[df['Type 2'] == 'Flying']
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard      Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 15    12                 Butterfree       Bug  Flying   60      45       50
# 20    16                     Pidgey    Normal  Flying   40      45       40
# 21    17                  Pidgeotto    Normal  Flying   63      60       55
# ..   ...                        ...       ...     ...  ...     ...      ...
# 730  662                Fletchinder      Fire  Flying   62      73       55
# 731  663                 Talonflame      Fire  Flying   78      81       71
# 734  666                   Vivillon       Bug  Flying   80      52       50
# 771  701                   Hawlucha  Fighting  Flying   78      92       75
# 793  717                    Yveltal      Dark  Flying  126     131       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# #  SORTING/DESCRIBING DATA

# %%
#  Describe functions explains more statistical functions of the int and float in the dataframe. describe function does not work on an object i.e a string

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# SORTING FUNCTION
# Helps to sort value in a chronological order, either ascending or descending

# %%
df.sort_values('Name', ascending = False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Defense' )
# Out:
#        #                 Name    Type 1  Type 2   HP  Attack  Defense  \
# 121  113              Chansey    Normal     NaN  250       5        5
# 488  440              Happiny    Normal     NaN  100       5        5
# 261  242              Blissey    Normal     NaN  255      10       10
# 186  172                Pichu  Electric     NaN   20      40       15
# 188  174            Igglybuff    Normal   Fairy   90      30       15
# ..   ...                  ...       ...     ...  ...     ...      ...
# 414  377             Regirock      Rock     NaN   80     100      200
# 223  208              Steelix     Steel  Ground   75      85      200
# 333  306    AggronMega Aggron     Steel     NaN   70     140      230
# 230  213              Shuckle       Bug    Rock   20      10      230
# 224  208  SteelixMega Steelix     Steel  Ground   75     125      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 121       35      105     50           1      False
# ...

# %%
df.sort_values(['Type 1', 'HP'])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending = [1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP', 'Defense'], ascending = [0,1,1])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 381  349                   Feebas  Water       NaN  20      15       20
# 139  129                 Magikarp  Water       NaN  20      10       55
# 129  120                   Staryu  Water       NaN  30      45       55
# 125  116                   Horsea  Water       NaN  30      40       70
# 106   98                   Krabby  Water       NaN  30     105       90
# ..   ...                      ...    ...       ...  ..     ...      ...
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 698  637                Volcarona    Bug      Fire  85      60       65
# 520  469                  Yanmega    Bug    Flying  86      76       86
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # MAKING CHANGES TO THE DATA

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Adding a new column to the dataframe. A very interesting thing about this is that there are several ways to do this and we will get the same answers.

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df['Total']
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: Total, Length: 800, dtype: int64

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# Jupyter automatically adds the new column to the existing one and then it becomes the df. To remove the new column subsequently, we make use of the DROP FUNCTION

# %%
new_df = df.drop(columns = ['Total'])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# df.drop(columns = ['Total'], inplace= True, axis=1)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# This is the second way of adding a new column

df['Total'] = df.iloc[:,4:10]. sum( axis = 1)

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df = df.drop(columns = ['Total'])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Changing the location of a column

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:] ]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## SAVING OUR DATA( EXPORTING INTO SDESIRED FORMAT)

# %%
# SAVING INTO CSV

# %%
df.to_csv('modified.csv')

# %%
df.to_excel('modified.xlsx')

# %%
df.to_csv('modified.csv', index = False)

# %%
df.to_csv('modified.txt', index = True, sep = '\t')

# %% [markdown]
# # FILTERING DATA

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# There is something very important to note here. The 'and' function used in normal python is replaced b the '&' function while the 'or' function in normal python is replaced by the '|' function.

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass    Poison      False   45      49
# 1      2                Ivysaur  Grass    Poison      False   60      62
# 2      3               Venusaur  Grass    Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass    Poison      False   80     100
# 48    43                 Oddish  Grass    Poison      False   45      50
# ..   ...                    ...    ...       ...        ...  ...     ...
# 718  650                Chespin  Grass       NaN      False   56      61
# 719  651              Quilladin  Grass       NaN      False   61      78
# 720  652             Chesnaught  Grass  Fighting      False   88     107
# 740  672                 Skiddo  Grass       NaN      False   66      65
# 741  673                 Gogoat  Grass       NaN      False  123     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Use of the 'and' function

df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False   45      49
# 1      2                Ivysaur  Grass  Poison      False   60      62
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 48    43                 Oddish  Grass  Poison      False   45      50
# 49    44                  Gloom  Grass  Poison      False   60      65
# 50    45              Vileplume  Grass  Poison      False   75      80
# 75    69             Bellsprout  Grass  Poison      False   50      75
# 76    70             Weepinbell  Grass  Poison      False   65      90
# 77    71             Victreebel  Grass  Poison      False   80     105
# 344  315                Roselia  Grass  Poison      False   50      60
# 451  406                  Budew  Grass  Poison      False   40      30
# ...

# %%
# Use of the 'or' function

df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1    Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass    Poison      False   45      49
# 1      2                Ivysaur  Grass    Poison      False   60      62
# 2      3               Venusaur  Grass    Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass    Poison      False   80     100
# 16    13                 Weedle    Bug    Poison      False   40      35
# ..   ...                    ...    ...       ...        ...  ...     ...
# 718  650                Chespin  Grass       NaN      False   56      61
# 719  651              Quilladin  Grass       NaN      False   61      78
# 720  652             Chesnaught  Grass  Fighting      False   88     107
# 740  672                 Skiddo  Grass       NaN      False   66      65
# 741  673                 Gogoat  Grass       NaN      False  123     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 50    45              Vileplume  Grass  Poison      False   75      80
# 77    71             Victreebel  Grass  Poison      False   80     105
# 652  591              Amoonguss  Grass  Poison      False  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 50        85      110       90     50           1      False
# 77        65      100       70     70           1      False
# 652       70       85       80     30           5      False

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 50    45              Vileplume  Grass  Poison      False   75      80
# 77    71             Victreebel  Grass  Poison      False   80     105
# 652  591              Amoonguss  Grass  Poison      False  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 50        85      110       90     50           1      False
# 77        65      100       70     70           1      False
# 652       70       85       80     30           5      False

# %%
new_df.to_csv('new_filtered.csv')

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Legendary  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison      False  45      49       49
# 1  2                Ivysaur  Grass  Poison      False  60      62       63
# 2  3               Venusaur  Grass  Poison      False  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison      False  80     100      123
# 4  4             Charmander   Fire     NaN      False  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 50    45              Vileplume  Grass  Poison      False   75      80
# 77    71             Victreebel  Grass  Poison      False   80     105
# 652  591              Amoonguss  Grass  Poison      False  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 50        85      110       90     50           1      False
# 77        65      100       70     70           1      False
# 652       70       85       80     30           5      False

# %%
new_df.reset_index()
# Out:
#    index    #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      2    3               Venusaur  Grass  Poison      False   80      82
# 1      3    3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 2     50   45              Vileplume  Grass  Poison      False   75      80
# 3     77   71             Victreebel  Grass  Poison      False   80     105
# 4    652  591              Amoonguss  Grass  Poison      False  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       83      100      100     80           1      False
# 1      123      122      120     80           1      False
# 2       85      110       90     50           1      False
# 3       65      100       70     70           1      False
# 4       70       85       80     30           5      False

# %%
new_df.reset_index(drop = True)
# Out:
#      #                   Name Type 1  Type 2  Legendary   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison      False   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison      False   80     100      123
# 2   45              Vileplume  Grass  Poison      False   75      80       85
# 3   71             Victreebel  Grass  Poison      False   80     105       65
# 4  591              Amoonguss  Grass  Poison      False  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
new_df.drop(['Name'], axis = 1)
# Out:
#        # Type 1  Type 2  Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 2      3  Grass  Poison      False   80      82       83      100      100
# 3      3  Grass  Poison      False   80     100      123      122      120
# 50    45  Grass  Poison      False   75      80       85      110       90
# 77    71  Grass  Poison      False   80     105       65      100       70
# 652  591  Grass  Poison      False  114      85       70       85       80
#
#      Speed  Generation  Legendary
# 2       80           1      False
# 3       80           1      False
# 50      50           1      False
# 77      70           1      False
# 652     30           5      False

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Legendary   HP  \
# 3      3      VenusaurMega Venusaur     Grass    Poison      False   80
# 7      6  CharizardMega Charizard X      Fire    Dragon      False   78
# 8      6  CharizardMega Charizard Y      Fire    Flying      False   78
# 12     9    BlastoiseMega Blastoise     Water       NaN      False   79
# 19    15      BeedrillMega Beedrill       Bug    Poison      False   65
# 23    18        PidgeotMega Pidgeot    Normal    Flying      False   83
# 71    65      AlakazamMega Alakazam   Psychic       NaN      False   55
# 87    80        SlowbroMega Slowbro     Water   Psychic      False   95
# 102   94          GengarMega Gengar     Ghost    Poison      False   60
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN      False  105
# 137  127          PinsirMega Pinsir       Bug    Flying      False   65
# 141  130      GyaradosMega Gyarados     Water      Dark      False   95
# ...

# %%
df.loc[df['Speed'] > 85]
# Out:
#        #                       Name  Type 1  Type 2  Legendary   HP  Attack  \
# 6      6                  Charizard    Fire  Flying      False   78      84
# 7      6  CharizardMega Charizard X    Fire  Dragon      False   78     130
# 8      6  CharizardMega Charizard Y    Fire  Flying      False   78     104
# 19    15      BeedrillMega Beedrill     Bug  Poison      False   65     150
# 22    18                    Pidgeot  Normal  Flying      False   83      80
# ..   ...                        ...     ...     ...        ...  ...     ...
# 791  715                    Noivern  Flying  Dragon      False   85      70
# 792  716                    Xerneas   Fairy     NaN       True  126     131
# 793  717                    Yveltal    Dark  Flying       True  126     131
# 794  718           Zygarde50% Forme  Dragon  Ground       True  108     100
# 796  719        DiancieMega Diancie    Rock   Fairy       True   50     160
#
# ...

# %%
# '!=' function is replaced by a '~' function in pandas

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Legendary   HP  Attack  \
# 0      1            Bulbasaur    Grass  Poison      False   45      49
# 1      2              Ivysaur    Grass  Poison      False   60      62
# 2      3             Venusaur    Grass  Poison      False   80      82
# 4      4           Charmander     Fire     NaN      False   39      52
# 5      5           Charmeleon     Fire     NaN      False   58      64
# ..   ...                  ...      ...     ...        ...  ...     ...
# 794  718     Zygarde50% Forme   Dragon  Ground       True  108     100
# 795  719              Diancie     Rock   Fairy       True   50     100
# 797  720  HoopaHoopa Confined  Psychic   Ghost       True   80     110
# 798  720   HoopaHoopa Unbound  Psychic    Dark       True   80     160
# 799  721            Volcanion     Fire   Water       True   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass', regex = True)]
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False   45      49
# 1      2                Ivysaur  Grass  Poison      False   60      62
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 4      4             Charmander   Fire     NaN      False   39      52
# ..   ...                    ...    ...     ...        ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False   62      50
# 736  668                 Pyroar   Fire  Normal      False   86      68
# 740  672                 Skiddo  Grass     NaN      False   66      65
# 741  673                 Gogoat  Grass     NaN      False  123     100
# 799  721              Volcanion   Fire   Water       True   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass')]
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False   45      49
# 1      2                Ivysaur  Grass  Poison      False   60      62
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 4      4             Charmander   Fire     NaN      False   39      52
# ..   ...                    ...    ...     ...        ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False   62      50
# 736  668                 Pyroar   Fire  Normal      False   86      68
# 740  672                 Skiddo  Grass     NaN      False   66      65
# 741  673                 Gogoat  Grass     NaN      False  123     100
# 799  721              Volcanion   Fire   Water       True   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'].str.startswith('Pi')]
# Out:
#        #                 Name    Type 1    Type 2  Legendary   HP  Attack  \
# 20    16               Pidgey    Normal    Flying      False   40      45
# 21    17            Pidgeotto    Normal    Flying      False   63      60
# 22    18              Pidgeot    Normal    Flying      False   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False   83      80
# 30    25              Pikachu  Electric       NaN      False   35      55
# 136  127               Pinsir       Bug       NaN      False   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying      False   65     155
# 186  172                Pichu  Electric       NaN      False   20      40
# 219  204               Pineco       Bug       NaN      False   50      65
# 239  221            Piloswine       Ice    Ground      False  100     100
# 438  393               Piplup     Water       NaN      False   53      51
# 558  499              Pignite      Fire  Fighting      False   90      93
# ...

# %% [markdown]
# # CONDITIONAL CHANGES

# %%
 df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1' ] = 'Flamer'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander   Flamer     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion   Flamer   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1'] == 'Flamer', 'Type 1' ] = 'Fire'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['HP'] < 85, 'Type 2'] == 'TEST VALUE'

df
# Out:
#        #                   Name   Type 1      Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  TEST VALUE      False  45      49
# 1      2                Ivysaur    Grass  TEST VALUE      False  60      62
# 2      3               Venusaur    Grass  TEST VALUE      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  TEST VALUE      False  80     100
# 4      4             Charmander     Fire  TEST VALUE      False  39      52
# ..   ...                    ...      ...         ...        ...  ..     ...
# 795  719                Diancie     Rock  TEST VALUE       True  50     100
# 796  719    DiancieMega Diancie     Rock  TEST VALUE       True  50     160
# 797  720    HoopaHoopa Confined  Psychic  TEST VALUE       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic  TEST VALUE       True  80     160
# 799  721              Volcanion     Fire  TEST VALUE       True  80     110
#
# ...

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary' ] == False
# Out:
#      Legendary  Legendary
# 4         True       True
# 5         True       True
# 6         True       True
# 7         True       True
# 8         True       True
# 42        True       True
# 43        True       True
# 63        True       True
# 64        True       True
# 83        True       True
# 84        True       True
# 135       True       True
# 147       True       True
# 158      False      False
# 169       True       True
# 170       True       True
# 171       True       True
# 236       True       True
# 237       True       True
# 259       True       True
# 263      False      False
# 270      False      False
# 276       True       True
# 277       True       True
# 278       True       True
# 279       True       True
# 352       True       True
# 353       True       True
# 354       True       True
# 355       True       True
# 435       True       True
# 436       True       True
# 437       True       True
# 518       True       True
# ...

# %%
df
# Out:
#        #                   Name   Type 1      Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  TEST VALUE      False  45      49
# 1      2                Ivysaur    Grass  TEST VALUE      False  60      62
# 2      3               Venusaur    Grass  TEST VALUE      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  TEST VALUE      False  80     100
# 4      4             Charmander     Fire  TEST VALUE      False  39      52
# ..   ...                    ...      ...         ...        ...  ..     ...
# 795  719                Diancie     Rock  TEST VALUE       True  50     100
# 796  719    DiancieMega Diancie     Rock  TEST VALUE       True  50     160
# 797  720    HoopaHoopa Confined  Psychic  TEST VALUE       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic  TEST VALUE       True  80     160
# 799  721              Volcanion     Fire  TEST VALUE       True  80     110
#
# ...

# %%
df
# Out:
#        #                   Name   Type 1      Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  TEST VALUE      False  45      49
# 1      2                Ivysaur    Grass  TEST VALUE      False  60      62
# 2      3               Venusaur    Grass  TEST VALUE      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  TEST VALUE      False  80     100
# 4      4             Charmander     Fire  TEST VALUE      False  39      52
# ..   ...                    ...      ...         ...        ...  ..     ...
# 795  719                Diancie     Rock  TEST VALUE       True  50     100
# 796  719    DiancieMega Diancie     Rock  TEST VALUE       True  50     160
# 797  720    HoopaHoopa Confined  Psychic  TEST VALUE       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic  TEST VALUE       True  80     160
# 799  721              Volcanion     Fire  TEST VALUE       True  80     110
#
# ...

# %%
df.loc[df['Type 1'] == 'Grass', ['HP','Attack']] == ['Test 1','Test 2']
# Out:
#         HP  Attack
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 48   False   False
# ..     ...     ...
# 718  False   False
# 719  False   False
# 720  False   False
# 740  False   False
# 741  False   False
#
# [70 rows x 2 columns]

# %%
df
# Out:
#        #                   Name   Type 1      Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  TEST VALUE      False  45      49
# 1      2                Ivysaur    Grass  TEST VALUE      False  60      62
# 2      3               Venusaur    Grass  TEST VALUE      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  TEST VALUE      False  80     100
# 4      4             Charmander     Fire  TEST VALUE      False  39      52
# ..   ...                    ...      ...         ...        ...  ..     ...
# 795  719                Diancie     Rock  TEST VALUE       True  50     100
# 796  719    DiancieMega Diancie     Rock  TEST VALUE       True  50     160
# 797  720    HoopaHoopa Confined  Psychic  TEST VALUE       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic  TEST VALUE       True  80     160
# 799  721              Volcanion     Fire  TEST VALUE       True  80     110
#
# ...

# %% [markdown]
# # AGGREGATE STATISTICS(GROUPBY)
# There are 3 things you can use groupby for:
# 1. Sum
# 2. Mean
# 3. Count

# %%
df = pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary.1
# ...

# %%
df.drop('Legendary.1', axis = 1)
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0         49       65       65     45           1
# ...

# %%
cols = list(df.columns)

# %%
df = cols[0:4] + [cols[5:11]] + [cols[4]]

# %%
df = pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary.1
# ...

# %%
# Grouping the parameters in a dateframe based on some specific values

# %%
df.groupby(['Type 1'])

# %%
df.groupby(['Type 1']).mean()
# Out:
#                    #  Legendary.1  Legendary         HP      Attack  \
# Type 1
# Bug       334.492754     0.000000   0.000000  56.884058   70.971014
# Dark      461.354839     0.064516   0.064516  66.806452   88.387097
# Dragon    474.375000     0.375000   0.375000  83.312500  112.125000
# Electric  363.500000     0.090909   0.090909  59.795455   69.090909
# Fairy     449.529412     0.058824   0.058824  74.117647   61.529412
# Fighting  363.851852     0.000000   0.000000  69.851852   96.777778
# Fire      327.403846     0.096154   0.096154  69.903846   84.769231
# Flying    677.750000     0.500000   0.500000  70.750000   78.750000
# Ghost     486.500000     0.062500   0.062500  64.437500   73.781250
# Grass     344.871429     0.042857   0.042857  67.271429   73.214286
# Ground    356.281250     0.125000   0.125000  73.781250   95.750000
# Ice       423.541667     0.083333   0.083333  72.000000   72.750000
# Normal    319.173469     0.020408   0.020408  77.275510   73.469388
# ...

# %%
df = df.drop('Legendary.1' , axis =1 )

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0         49       65       65     45           1
# ...

# %%
df.groupby(['Type 1']).mean()
# Out:
#                    #  Legendary         HP      Attack     Defense    Sp. Atk  \
# Type 1
# Bug       334.492754   0.000000  56.884058   70.971014   70.724638  53.869565
# Dark      461.354839   0.064516  66.806452   88.387097   70.225806  74.645161
# Dragon    474.375000   0.375000  83.312500  112.125000   86.375000  96.843750
# Electric  363.500000   0.090909  59.795455   69.090909   66.295455  90.022727
# Fairy     449.529412   0.058824  74.117647   61.529412   65.705882  78.529412
# Fighting  363.851852   0.000000  69.851852   96.777778   65.925926  53.111111
# Fire      327.403846   0.096154  69.903846   84.769231   67.769231  88.980769
# Flying    677.750000   0.500000  70.750000   78.750000   66.250000  94.250000
# Ghost     486.500000   0.062500  64.437500   73.781250   81.187500  79.343750
# Grass     344.871429   0.042857  67.271429   73.214286   70.800000  77.500000
# Ground    356.281250   0.125000  73.781250   95.750000   84.843750  56.468750
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)
# Out:
#                    #  Legendary         HP      Attack     Defense    Sp. Atk  \
# Type 1
# Steel     442.851852   0.148148  65.222222   92.703704  126.370370  67.518519
# Rock      392.727273   0.090909  65.363636   92.863636  100.795455  63.340909
# Dragon    474.375000   0.375000  83.312500  112.125000   86.375000  96.843750
# Ground    356.281250   0.125000  73.781250   95.750000   84.843750  56.468750
# Ghost     486.500000   0.062500  64.437500   73.781250   81.187500  79.343750
# Water     303.089286   0.035714  72.062500   74.151786   72.946429  74.812500
# Ice       423.541667   0.083333  72.000000   72.750000   71.416667  77.541667
# Grass     344.871429   0.042857  67.271429   73.214286   70.800000  77.500000
# Bug       334.492754   0.000000  56.884058   70.971014   70.724638  53.869565
# Dark      461.354839   0.064516  66.806452   88.387097   70.225806  74.645161
# Poison    251.785714   0.000000  67.250000   74.678571   68.821429  60.428571
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Attack', ascending = False)
# Out:
#                    #  Legendary         HP      Attack     Defense    Sp. Atk  \
# Type 1
# Dragon    474.375000   0.375000  83.312500  112.125000   86.375000  96.843750
# Fighting  363.851852   0.000000  69.851852   96.777778   65.925926  53.111111
# Ground    356.281250   0.125000  73.781250   95.750000   84.843750  56.468750
# Rock      392.727273   0.090909  65.363636   92.863636  100.795455  63.340909
# Steel     442.851852   0.148148  65.222222   92.703704  126.370370  67.518519
# Dark      461.354839   0.064516  66.806452   88.387097   70.225806  74.645161
# Fire      327.403846   0.096154  69.903846   84.769231   67.769231  88.980769
# Flying    677.750000   0.500000  70.750000   78.750000   66.250000  94.250000
# Poison    251.785714   0.000000  67.250000   74.678571   68.821429  60.428571
# Water     303.089286   0.035714  72.062500   74.151786   72.946429  74.812500
# Ghost     486.500000   0.062500  64.437500   73.781250   81.187500  79.343750
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending = False)
# Out:
#                    #  Legendary         HP      Attack     Defense    Sp. Atk  \
# Type 1
# Dragon    474.375000   0.375000  83.312500  112.125000   86.375000  96.843750
# Normal    319.173469   0.020408  77.275510   73.469388   59.846939  55.816327
# Fairy     449.529412   0.058824  74.117647   61.529412   65.705882  78.529412
# Ground    356.281250   0.125000  73.781250   95.750000   84.843750  56.468750
# Water     303.089286   0.035714  72.062500   74.151786   72.946429  74.812500
# Ice       423.541667   0.083333  72.000000   72.750000   71.416667  77.541667
# Flying    677.750000   0.500000  70.750000   78.750000   66.250000  94.250000
# Psychic   380.807018   0.245614  70.631579   71.456140   67.684211  98.403509
# Fire      327.403846   0.096154  69.903846   84.769231   67.769231  88.980769
# Fighting  363.851852   0.000000  69.851852   96.777778   65.925926  53.111111
# Grass     344.871429   0.042857  67.271429   73.214286   70.800000  77.500000
# ...

# %%
# Sum

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #  Legendary    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       23080          0  3925    4897     4880     3717     4471   4256
# Dark      14302          2  2071    2740     2177     2314     2155   2361
# Dragon    15180         12  2666    3588     2764     3099     2843   2657
# Electric  15994          4  2631    3040     2917     3961     3243   3718
# Fairy      7642          1  1260    1046     1117     1335     1440    826
# Fighting   9824          0  1886    2613     1780     1434     1747   1784
# Fire      17025          5  3635    4408     3524     4627     3755   3871
# Flying     2711          2   283     315      265      377      290    410
# Ghost     15568          2  2062    2361     2598     2539     2447   2059
# Grass     24141          3  4709    5125     4956     5425     4930   4335
# Ground    11401          4  2361    3064     2715     1807     2008   2045
# ...

# %%
df.groupby(['Type 1']). count()
# Out:
#             #  Name  Type 2  Legendary   HP  Attack  Defense  Sp. Atk  \
# Type 1
# Bug        69    69      52         69   69      69       69       69
# Dark       31    31      21         31   31      31       31       31
# Dragon     32    32      21         32   32      32       32       32
# Electric   44    44      17         44   44      44       44       44
# Fairy      17    17       2         17   17      17       17       17
# Fighting   27    27       7         27   27      27       27       27
# Fire       52    52      24         52   52      52       52       52
# Flying      4     4       2          4    4       4        4        4
# Ghost      32    32      22         32   32      32       32       32
# Grass      70    70      37         70   70      70       70       70
# Ground     32    32      19         32   32      32       32       32
# Ice        24    24      11         24   24      24       24       24
# ...

# %%
df.groupby(['Type 1']). count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']). count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
